# %% [markdown]
# ## BIP Technical Test
#
# ### **Resume.**
#
# #### Write a function that finds the contiguous subarray (containing at least one number) which has the largest sum within an array read in input to the function. The function should return the sub-array and the corresponding sum. Which is the complexity of your solution? Can you do a solution with linear complexity? Write a unit test for the function.

# %%
def contiguous_subarray(array, size):
    '''
        The function receives an array of numbers and a size of the subarray and returns the largest sum
        of all the subarrays in the initial arrays
        
        Params.
        -------
        array = array of integers
        size = integer
        
        Returns.
        --------
        The largest sum and the subarray that gives this sum
    '''
    if size == 0 or len(array)<size:
        if size == 0:
            return print('Please introduce de correct params, size will be greater than 0')
        if len(array)<size:
            return print(f'The size of subarray "{size}" is greater than size of the initial array "{len(array)}"')
    else:
        solution_array=[]
        for i in range((len(array)+1-size)+1):
            temp = array[i:i+size]
            if i>0 and sum(solution_array)<sum(temp):
                solution_array=temp
    
    return print(f'The largest sum of the array given is {sum(solution_array)} and the subarray is {solution_array}')

# %%
import numpy as np

def TDD(v):
    
    '''
        This function is a battery of test to test the principal function.
        
        Params.
        ------
        v = int, indicate the number of tests.
        Returns.
        -------
        The functions returns the results of the diferents test that it apply.
    '''
    array = np.random.randint(30, size=40)
    print(array)
    for i in range(v+1):
        print(f'For size equals {i}....')
        contiguous_subarray(array,i)

TDD(41)
# Out:
# [26  1  1 17 24  0 17  1 18  3 28  1  8 22 20  3 13  1 20 17 10 21 13 15
#  11 16 16  5  3 18 28  7 15 20 28  2  9 20  9 26]
# For size equals 0....
# Please introduce de correct params, size will be greater than 0
# For size equals 1....
# The largest sum of the array given is 28 and the subarray is [28]
# For size equals 2....
# The largest sum of the array given is 48 and the subarray is [20 28]
# For size equals 3....
# The largest sum of the array given is 63 and the subarray is [15 20 28]
# For size equals 4....
# The largest sum of the array given is 70 and the subarray is [28  7 15 20]
# For size equals 5....
# The largest sum of the array given is 98 and the subarray is [28  7 15 20 28]
# For size equals 6....
# The largest sum of the array given is 116 and the subarray is [18 28  7 15 20 28]
# For size equals 7....
# The largest sum of the array given is 119 and the subarray is [ 3 18 28  7 15 20 28]
# For size equals 8....
# The largest sum of the array given is 129 and the subarray is [28  7 15 20 28  2  9 20]
# For size equals 9....
# The largest sum of the array given is 147 and the subarray is [18 28  7 15 20 28  2  9 20]
# For size equals 10....
# The largest sum of the array given is 164 and the subarray is [28  7 15 20 28  2  9 20  9 26]
# For size equals 11....
# The largest sum of the array given is 182 and the subarray is [18 28  7 15 20 28  2  9 20  9 26]
# For size equals 12....
# The largest sum of the array given is 185 and the subarray is [ 3 18 28  7 15 20 28  2  9 20  9 26]
# For size equals 13....
# The largest sum of the array given is 195 and the subarray is [13 15 11 16 16  5  3 18 28  7 15 20 28]
# For size equals 14....
# The largest sum of the array given is 216 and the subarray is [21 13 15 11 16 16  5  3 18 28  7 15 20 28]
# For size equals 15....
# The largest sum of the array given is 226 and the subarray is [10 21 13 15 11 16 16  5  3 18 28  7 15 20 28]
# For size equals 16....
# The largest sum of the array given is 243 and the subarray is [17 10 21 13 15 11 16 16  5  3 18 28  7 15 20 28]
# For size equals 17....
# The largest sum of the array given is 263 and the subarray is [20 17 10 21 13 15 11 16 16  5  3 18 28  7 15 20 28]
# For size equals 18....
# The largest sum of the array given is 265 and the subarray is [20 17 10 21 13 15 11 16 16  5  3 18 28  7 15 20 28  2]
# For size equals 19....
# The largest sum of the array given is 282 and the subarray is [21 13 15 11 16 16  5  3 18 28  7 15 20 28  2  9 20  9 26]
# For size equals 20....
# The largest sum of the array given is 294 and the subarray is [20 17 10 21 13 15 11 16 16  5  3 18 28  7 15 20 28  2  9 20]
# For size equals 21....
# The largest sum of the array given is 309 and the subarray is [17 10 21 13 15 11 16 16  5  3 18 28  7 15 20 28  2  9 20  9 26]
# For size equals 22....
# The largest sum of the array given is 329 and the subarray is [20 17 10 21 13 15 11 16 16  5  3 18 28  7 15 20 28  2  9 20  9 26]
# For size equals 23....
# The largest sum of the array given is 330 and the subarray is [ 8 22 20  3 13  1 20 17 10 21 13 15 11 16 16  5  3 18 28  7 15 20 28]
# For size equals 24....
# The largest sum of the array given is 343 and the subarray is [13  1 20 17 10 21 13 15 11 16 16  5  3 18 28  7 15 20 28  2  9 20  9 26]
# For size equals 25....
# The largest sum of the array given is 359 and the subarray is [28  1  8 22 20  3 13  1 20 17 10 21 13 15 11 16 16  5  3 18 28  7 15 20
#  28]
# For size equals 26....
# The largest sum of the array given is 366 and the subarray is [20  3 13  1 20 17 10 21 13 15 11 16 16  5  3 18 28  7 15 20 28  2  9 20
#   9 26]
# For size equals 27....
# The largest sum of the array given is 388 and the subarray is [22 20  3 13  1 20 17 10 21 13 15 11 16 16  5  3 18 28  7 15 20 28  2  9
#  20  9 26]
# For size equals 28....
# The largest sum of the array given is 396 and the subarray is [ 8 22 20  3 13  1 20 17 10 21 13 15 11 16 16  5  3 18 28  7 15 20 28  2
#   9 20  9 26]
# For size equals 29....
# The largest sum of the array given is 399 and the subarray is [28  1  8 22 20  3 13  1 20 17 10 21 13 15 11 16 16  5  3 18 28  7 15 20
#  28  2  9 20  9]
# For size equals 30....
# The largest sum of the array given is 425 and the subarray is [28  1  8 22 20  3 13  1 20 17 10 21 13 15 11 16 16  5  3 18 28  7 15 20
#  28  2  9 20  9 26]
# For size equals 31....
# The largest sum of the array given is 428 and the subarray is [ 3 28  1  8 22 20  3 13  1 20 17 10 21 13 15 11 16 16  5  3 18 28  7 15
#  20 28  2  9 20  9 26]
# For size equals 32....
# The largest sum of the array given is 446 and the subarray is [18  3 28  1  8 22 20  3 13  1 20 17 10 21 13 15 11 16 16  5  3 18 28  7
#  15 20 28  2  9 20  9 26]
# For size equals 33....
# The largest sum of the array given is 447 and the subarray is [ 1 18  3 28  1  8 22 20  3 13  1 20 17 10 21 13 15 11 16 16  5  3 18 28
#   7 15 20 28  2  9 20  9 26]
# For size equals 34....
# The largest sum of the array given is 464 and the subarray is [17  1 18  3 28  1  8 22 20  3 13  1 20 17 10 21 13 15 11 16 16  5  3 18
#  28  7 15 20 28  2  9 20  9 26]
# For size equals 35....
# The largest sum of the array given is 470 and the subarray is [17 24  0 17  1 18  3 28  1  8 22 20  3 13  1 20 17 10 21 13 15 11 16 16
#   5  3 18 28  7 15 20 28  2  9 20]
# For size equals 36....
# The largest sum of the array given is 488 and the subarray is [24  0 17  1 18  3 28  1  8 22 20  3 13  1 20 17 10 21 13 15 11 16 16  5
#   3 18 28  7 15 20 28  2  9 20  9 26]
# For size equals 37....
# The largest sum of the array given is 505 and the subarray is [17 24  0 17  1 18  3 28  1  8 22 20  3 13  1 20 17 10 21 13 15 11 16 16
#   5  3 18 28  7 15 20 28  2  9 20  9 26]
# For size equals 38....
# The largest sum of the array given is 506 and the subarray is [ 1 17 24  0 17  1 18  3 28  1  8 22 20  3 13  1 20 17 10 21 13 15 11 16
#  16  5  3 18 28  7 15 20 28  2  9 20  9 26]
# For size equals 39....
# The largest sum of the array given is 507 and the subarray is [ 1  1 17 24  0 17  1 18  3 28  1  8 22 20  3 13  1 20 17 10 21 13 15 11
#  16 16  5  3 18 28  7 15 20 28  2  9 20  9 26]
# For size equals 40....
# The largest sum of the array given is 507 and the subarray is [ 1  1 17 24  0 17  1 18  3 28  1  8 22 20  3 13  1 20 17 10 21 13 15 11
#  16 16  5  3 18 28  7 15 20 28  2  9 20  9 26]
# For size equals 41....
# The size of subarray "41" is greater than size of the initial array "40"
